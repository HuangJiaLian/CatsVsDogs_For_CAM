# %%
from tensorflow.keras.models import load_model

# %%
# 加载训练好的网络模型
test_model = load_model('cat_dog_cam_classifier.h5')

# %%
# 看网络的结构
test_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 298, 298, 16)      160
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 149, 149, 16)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 147, 147, 32)      4640
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 71, 71, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 33, 33, 128)       73856
# ...

# %%
import cv2
def cvLoadImg(path):
    img = mpimg.imread(path)
    img = cv2.resize(img, dsize=(300, 300), interpolation=cv2.INTER_CUBIC)/255.
    img = np.expand_dims(img, axis=0)
    img = np.expand_dims(img, axis=-1)
    return img

# %%
from keras.preprocessing import image
import numpy as np
import os
import time
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow.keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
def isCat(path):
    test_img = cvLoadImg(path)
    classes = test_model.predict(test_img)
    class_idx = np.argmax(classes[0])
    if class_idx == 0:
        return True
    else:
        return False

# %%
# 开始测试
test_path = './test_images/'
test_list = os.listdir(test_path)

# %%
def test(path):
    if isCat(path) == True:
        print('This is a cat.')
    else:
        print('This is a dog.')
    img = mpimg.imread(path)
    plt.axis('Off')
    plt.imshow(img,cmap='gray')

# %%
test(test_path+test_list[0])
# Out:
# This is a dog.

# %%
test(test_path+test_list[1])
# Out:
# This is a cat.

# %%
test(test_path+test_list[2])
# Out:
# This is a cat.

# %%
test(test_path+test_list[3])
# Out:
# This is a cat.

# %%
test(test_path+test_list[4])
# Out:
# This is a cat.

# %%
test(test_path+test_list[5])
# Out:
# This is a dog.

# %%
test(test_path+test_list[6])
# Out:
# This is a dog.

# %%
test(test_path+test_list[7])
# Out:
# This is a cat.

# %%
test(test_path+test_list[8])
# Out:
# This is a cat.

# %%
test(test_path+test_list[9])
# Out:
# This is a dog.

# %%
test(test_path+test_list[10])
# Out:
# This is a cat.

# %%
test(test_path+test_list[11])
# Out:
# This is a dog.

# %%
test(test_path+test_list[12])
# Out:
# This is a dog.

# %%
test(test_path+test_list[13])
# Out:
# This is a dog.

# %%
test(test_path+test_list[14])
# Out:
# This is a cat.

# %%
test(test_path+test_list[15])
# Out:
# This is a dog.

# %%
test(test_path+test_list[16])
# Out:
# This is a dog.

# %%
test(test_path+test_list[17])
# Out:
# This is a dog.

# %%
test(test_path+test_list[18])
# Out:
# This is a cat.

# %%
test(test_path+test_list[19])
# Out:
# This is a cat.

# %%
test(test_path+test_list[20])
# Out:
# This is a cat.
